# %% [markdown]
# <a href="https://colab.research.google.com/github/brendanpshea/colab-utilities/blob/main/Mermaid_in)Colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import base64

graph = """
erDiagram
    User {
        INT id
        STRING name
        STRING email
    }

    Post {
        INT id
        STRING title
        TEXT content
        DATE created_at
    }

    Comment {
        INT id
        TEXT content
        DATE created_at
    }

    User ||--o{ Post : "creates"
    User ||--o{ Comment : "writes"
    Post ||--|{ Comment : "has"
"""

graphbytes = graph.encode("ascii")


base64_bytes = base64.b64encode(graphbytes)
base64_string = base64_bytes.decode("ascii")

import requests, io
from PIL import Image
import matplotlib.pyplot as plt

img = Image.open(io.BytesIO(requests.get('https://mermaid.ink/img/' + base64_string).content))
plt.imshow(img)
